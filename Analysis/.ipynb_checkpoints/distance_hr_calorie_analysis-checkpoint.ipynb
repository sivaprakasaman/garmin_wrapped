# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import scipy.interpolate

# %%
data_dir = 'Data'
datafile = 'Activities_Andrew.csv'
ignore_noHR = True;


run_identifiers = ["Running","Track Running","Trail Running"];
walk_identifiers = ["Walking"]
pwd = os.getcwd();
os.chdir('..')
os.chdir(data_dir);
all_activities = pd.read_csv(datafile)
os.chdir(pwd)

# %%
all_activities.head(10)
# Out:
#    Activity Type                 Date  Favorite  \
# 0        Cycling  2022-10-23 10:45:00     False
# 1        Running  2022-10-22 08:00:30     False
# 2        Running  2022-10-22 07:31:03     False
# 3        Running  2022-10-21 10:12:28     False
# 4        Running  2022-10-20 09:44:59     False
# 5  Indoor Rowing  2022-10-19 19:47:46     False
# 6        Running  2022-10-17 09:17:48     False
# 7        Running  2022-10-16 16:29:01     False
# 8        Running  2022-10-15 12:31:55     False
# 9        Running  2022-10-13 20:10:56     False
#
#                                       Title Distance Calories        Time  \
# 0                 Tippecanoe County Cycling     5.34      296    00:33:08
# 1  Tippecanoe County - Purdue half marathon    13.14    1,485    01:38:55
# 2                 Tippecanoe County Running     0.60       71  00:05:47.2
# 3                 Tippecanoe County Running     2.52      287    00:19:57
# 4                 Tippecanoe County Running     2.06      222    00:15:22
# 5                             Indoor Rowing    2,000       80  00:08:21.2
# 6                 Tippecanoe County Running     5.05      569    00:39:29
# 7                 Tippecanoe County Running     3.12      353    00:25:23
# 8                 Tippecanoe County Running     8.07      988    01:10:01
# 9                    West Lafayette Running     1.54      191    00:13:25
#
#   Avg HR Max HR Aerobic TE  ... Min Resp Max Resp Stress Change Stress Start  \
# 0    128    169        2.1  ...       --       --            --           --
# 1    181    190        5.0  ...       --       --            --           --
# 2    150    173        1.5  ...       --       --            --           --
# 3    169    184        3.1  ...       --       --            --           --
# 4    150    189        3.0  ...       --       --            --           --
# 5    129    182        1.3  ...       --       --            --           --
# 6    171    184        3.9  ...       --       --            --           --
# 7    163    185        3.2  ...       --       --            --           --
# 8    173    190        4.6  ...       --       --            --           --
# 9    159    174        2.8  ...       --       --            --           --
#
#   Stress End Avg Stress  Moving Time  Elapsed Time  Min Elevation  \
# 0         --         --     00:30:20      00:39:31            638
# 1         --         --     01:38:51      01:38:55            606
# 2         --         --   00:05:45.4    00:05:47.2            688
# 3         --         --     00:19:56      00:19:57            706
# 4         --         --     00:15:19      00:16:31            703
# 5         --         --     00:08:15    00:08:21.2             --
# 6         --         --     00:39:27      00:39:29            674
# 7         --         --     00:25:21      00:25:24            675
# 8         --         --     01:09:58      01:10:06            673
# 9         --         --     00:13:21      00:15:17            622
#
#    Max Elevation
# 0            731
# 1            720
# 2            703
# 3            731
# 4            723
# 5             --
# 6            709
# 7            708
# 8            713
# 9            638
#
# [10 rows x 51 columns]

# %%
all_activities = all_activities.replace(',','', regex=True) #make sure no commas in numeric data
all_activities = all_activities.replace('--',None, regex=True) #convert any -- to NaN to avoid crashes

all_activities['Calories'] = all_activities['Calories'].astype(float)
all_activities['Distance'] = all_activities['Distance'].astype(float)
all_activities['Avg HR'] = all_activities['Avg HR'].astype(float)
all_activities['Max HR'] = all_activities['Max HR'].astype(float)
all_activities['Time'] = all_activities['Time'].str.split(':').apply(lambda x: float(x[0]) * 60 + float(x[1])+float(x[2])/60)

if ignore_noHR:
    all_activities = all_activities[all_activities["Avg HR"]!=0]
    all_activities = all_activities[all_activities["Avg HR"]!=None]

print('Total Activities Loaded: ' + str(all_activities.shape[0]))

runs = all_activities.loc[all_activities["Activity Type"].isin(run_identifiers)];
walks = all_activities.loc[all_activities["Activity Type"].isin(walk_identifiers)];

#handle runs not logged in Miles...but Garmin not providing Units. 
#Assume any Track Running activity needs to be converted from meters to miles.

runs.loc[all_activities["Activity Type"] == "Track Running", "Distance"] = runs.loc[all_activities["Activity Type"] == "Track Running", "Distance"]/1609.34;


print('Total Runs Loaded: ' + str(runs.shape[0]))
print('Total Walks Loaded: ' + str(walks.shape[0]))

runs.head(20)
# Out:
# Total Activities Loaded: 955
# Total Runs Loaded: 537
# Total Walks Loaded: 23
# /home/sivaprakasaman/.local/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#     Activity Type                 Date  Favorite  \
# 1         Running  2022-10-22 08:00:30     False
# 2         Running  2022-10-22 07:31:03     False
# 3         Running  2022-10-21 10:12:28     False
# 4         Running  2022-10-20 09:44:59     False
# 6         Running  2022-10-17 09:17:48     False
# 7         Running  2022-10-16 16:29:01     False
# 8         Running  2022-10-15 12:31:55     False
# 9         Running  2022-10-13 20:10:56     False
# 10  Track Running  2022-10-13 19:37:36     False
# 11        Running  2022-10-13 19:31:32     False
# 14        Running  2022-10-11 10:05:17     False
# 19        Running  2022-10-08 11:43:46     False
# 20        Running  2022-10-07 10:11:59     False
# 21        Running  2022-10-06 09:15:07     False
# 24        Running  2022-10-04 09:19:00     False
# 28        Running  2022-10-01 11:45:46     False
# 29        Running  2022-09-29 09:07:43     False
# 35        Running  2022-09-22 08:43:51     False
# 39        Running  2022-09-20 08:53:19     False
# 44        Running  2022-09-17 11:42:41     False
#
#                                                 Title   Distance  Calories  \
# 1            Tippecanoe County - Purdue half marathon  13.140000    1485.0
# 2                           Tippecanoe County Running   0.600000      71.0
# 3                           Tippecanoe County Running   2.520000     287.0
# 4                           Tippecanoe County Running   2.060000     222.0
# 6                           Tippecanoe County Running   5.050000     569.0
# 7                           Tippecanoe County Running   3.120000     353.0
# 8                           Tippecanoe County Running   8.070000     988.0
# 9                              West Lafayette Running   1.540000     191.0
# 10                 West Lafayette - 6x800m 2 min rest   3.342985     388.0
# 11                             West Lafayette Running   0.510000      59.0
# 14         Tippecanoe County - 10k Progression @730-8   7.220000     882.0
# 19                    Tippecanoe County - 10 mile run  10.010000    1235.0
# 20                          Tippecanoe County Running   3.040000     346.0
# 21                          Tippecanoe County Running   4.030000     451.0
# 24  Tippecanoe County - 1mi warmup 5k TT 1mi cool ...   5.120000     553.0
# 28                          Tippecanoe County Running  13.150000    1559.0
# 29                          Tippecanoe County Running   4.010000     453.0
# 35                   Tippecanoe County - 1-3-1 @7:30s   5.220000     577.0
# 39                          Tippecanoe County Running   7.060000     810.0
# 44                          Tippecanoe County Running   5.000000     591.0
#
#           Time  Avg HR  Max HR Aerobic TE  ... Min Resp Max Resp  \
# 1    98.916667   181.0   190.0        5.0  ...       --       --
# 2     5.786667   150.0   173.0        1.5  ...       --       --
# 3    19.950000   169.0   184.0        3.1  ...       --       --
# 4    15.366667   150.0   189.0        3.0  ...       --       --
# 6    39.483333   171.0   184.0        3.9  ...       --       --
# 7    25.383333   163.0   185.0        3.2  ...       --       --
# 8    70.016667   173.0   190.0        4.6  ...       --       --
# 9    13.416667   159.0   174.0        2.8  ...       --       --
# 10   28.750000   155.0   197.0        3.4  ...       --       --
# 11    4.340000   124.0   145.0        1.5  ...       --       --
# 14   56.350000   175.0   196.0        5.0  ...       --       --
# 19   83.866667   177.0   190.0        5.0  ...        4        5
# 20   25.383333   166.0   177.0        3.1  ...        4        5
# 21   31.083333   172.0   195.0        3.7  ...        4        5
# 24   39.933333   172.0   194.0        3.8  ...        4        5
# 28  116.300000   178.0   194.0        5.0  ...        4        5
# 29   32.066667   176.0   191.0        3.5  ...        4        5
# 35   42.350000   168.0   191.0        3.7  ...        4        5
# 39   58.716667   178.0   190.0        4.4  ...        4        5
# 44   41.133333   179.0   197.0        3.9  ...        4        5
#
#    Stress Change Stress Start Stress End Avg Stress  Moving Time  \
# 1             --           --         --         --     01:38:51
# 2             --           --         --         --   00:05:45.4
# 3             --           --         --         --     00:19:56
# 4             --           --         --         --     00:15:19
# 6             --           --         --         --     00:39:27
# 7             --           --         --         --     00:25:21
# 8             --           --         --         --     01:09:58
# 9             --           --         --         --     00:13:21
# 10            --           --         --         --     00:27:30
# 11            --           --         --         --     00:04:19
# 14            --           --         --         --     00:56:15
# 19            10           83         93         90     01:23:43
# 20            10           83         93         90     00:25:22
# 21            10           83         93         90     00:30:58
# 24            10           83         93         90     00:39:49
# 28            10           83         93         90     01:55:23
# 29            10           83         93         90     00:31:58
# 35            10           83         93         90     00:41:58
# 39            10           83         93         90     00:58:21
# 44            10           83         93         90     00:40:39
#
#     Elapsed Time  Min Elevation  Max Elevation
# 1       01:38:55            606            720
# 2     00:05:47.2            688            703
# 3       00:19:57            706            731
# 4       00:16:31            703            723
# 6       00:39:29            674            709
# 7       00:25:24            675            708
# 8       01:10:06            673            713
# 9       00:15:17            622            638
# 10      00:28:45            625            630
# 11    00:04:20.4            626            634
# 14      00:58:22            673            714
# 19      01:26:47            637            730
# 20      00:25:23            676            702
# 21      00:31:05            677            702
# 24      00:41:59            676            712
# 28      02:16:06            526            722
# 29      00:33:39            676            702
# 35      00:42:35            676            708
# 39      01:11:07            681            815
# 44      00:56:14            660            699
#
# [20 rows x 51 columns]

# %%
# %matplotlib inline

ax1 = plt.subplot(1,2,1)
plt.scatter(x = runs["Distance"], y = runs["Calories"], c = runs["Calories"], cmap=plt.get_cmap('Reds_r'),alpha = .5)
plt.scatter(x = walks["Distance"], y = walks["Calories"], c = walks["Calories"], cmap=plt.get_cmap('Blues_r'),alpha = .5)
plt.xlabel('Distance')
plt.ylabel('Calories (Garmin Est.)');


ax2 = plt.subplot(1,2,2, sharey = ax1)
plt.scatter(x = runs["Time"], y = runs["Calories"], c = runs["Calories"], cmap=plt.get_cmap('Reds_r'),alpha = .5)
plt.scatter(x = walks["Time"], y = walks["Calories"], c = walks["Calories"], cmap=plt.get_cmap('Blues_r'),alpha = .5)
plt.text(x=5, y=600, s="N_runs = " + str(runs.shape[0]),c = 'firebrick') #hardcoded can fix this later
plt.text(x=75, y=450, s="N_walks = " + str(walks.shape[0]), c = 'cornflowerblue') #hardcoded can fix this later
plt.xlim([0,300])
box = ax2.get_position()
box.x0 = box.x0 + 0.03
box.x1 = box.x1 + 0.03
ax2.set_position(box)
plt.xlabel('Time in Activity')
plt.suptitle('Walking vs Running - Andrew')
plt.savefig('andrew_walkrun.jpg',dpi = 300)

# %%
#Average Calories/Mile burned by Pace

pace_r = runs["Time"]/runs["Distance"];
calspmi_r = runs["Calories"]/runs["Distance"];
calspmin_r = runs["Calories"]/runs["Time"];
avg_hr_r = runs["Avg HR"];

pace_w = walks["Time"]/walks["Distance"];
calspmi_w = walks["Calories"]/walks["Distance"];
calspmin_w = walks["Calories"]/walks["Time"];
avg_hr_w = walks["Avg HR"];


r_meancalspmi = np.ma.masked_invalid(calspmi_r).mean();
w_meancalspmi = np.ma.masked_invalid(calspmi_w).mean();

r_meancalspmin = np.ma.masked_invalid(calspmin_r).mean();
w_meancalspmin = np.ma.masked_invalid(calspmin_w).mean();

r_avg_hr = np.ma.masked_invalid(avg_hr_r).mean();
w_avg_hr = np.ma.masked_invalid(avg_hr_w).mean();

ax1 = plt.subplot(2,1,1);
plt.scatter(pace_r, calspmi_r, c = calspmi_r, cmap=plt.get_cmap('Reds_r'), alpha = .5)
plt.plot(np.arange(0,61),np.ones(61)*r_meancalspmi,'firebrick',linewidth=1.5, alpha = .5)
plt.text(x=50, y=r_meancalspmi-15, s="Avg = " + str(r_meancalspmi)[0:2],c = 'firebrick') #hardcoded can fix this later
plt.xlabel('Avg Pace (min/mi)');
plt.ylabel('Calories/Mile');

plt.scatter(pace_w, calspmi_w, c = calspmi_w, cmap=plt.get_cmap('Blues_r'), alpha = .5)
plt.plot(np.arange(0,61),np.ones(61)*w_meancalspmi,'cornflowerblue', linewidth=1.5, alpha = .5)
plt.text(x=50, y=w_meancalspmi+8, s="Avg = " + str(w_meancalspmi)[0:3],c = 'cornflowerblue') #hardcoded can fix this later
plt.xlim([3,60])


ax2 = plt.subplot(2,1,2, sharex=ax1);
plt.scatter(pace_r, calspmin_r, c = calspmin_r, cmap=plt.get_cmap('Reds'), alpha = .5)
plt.plot(np.arange(0,61),np.ones(61)*r_meancalspmin,'firebrick',linewidth=1.5, alpha = .5)
plt.text(x=50, y=r_meancalspmin, s="Avg = " + str(r_meancalspmin)[0:2],c = 'firebrick') #hardcoded can fix this later
plt.xlabel('Avg Pace (min/mi)');
plt.ylabel('Calories/Min');

plt.scatter(pace_w, calspmin_w, c = calspmin_w, cmap=plt.get_cmap('Blues'), alpha = .5)
plt.plot(np.arange(0,61),np.ones(61)*w_meancalspmin,'cornflowerblue', linewidth=1.5, alpha = .5)
plt.text(x=50, y=w_meancalspmin, s="Avg = " + str(w_meancalspmin)[0:3],c = 'cornflowerblue') #hardcoded can fix this later
plt.xlim([0,60])
plt.suptitle('Calories Burned as Pace Drops - Andrew')
plt.savefig('andrew_caloriepace.jpg',dpi = 300)


fig = plt.figure()
plt.scatter(pace_r, avg_hr_r, c = avg_hr_r, cmap=plt.get_cmap('Reds'), alpha = .5)
plt.text(x=50, y=r_avg_hr+3, s="Avg = " + str(r_avg_hr)[0:2],c = 'firebrick') #hardcoded can fix this later
plt.plot(np.arange(0,61),np.ones(61)*r_avg_hr,'firebrick',linewidth=1.5, alpha = .5)
plt.scatter(pace_w, avg_hr_w, c = avg_hr_w, cmap=plt.get_cmap('Blues'), alpha = .5)
plt.text(x=50, y=w_avg_hr+3, s="Avg = " + str(w_avg_hr)[0:2],c = 'cornflowerblue') #hardcoded can fix this later
plt.plot(np.arange(0,61),np.ones(61)*w_avg_hr,'cornflowerblue',linewidth=1.5, alpha = .5)
plt.xlabel('Avg Pace (min/mi)');
plt.ylabel('Calories/Mile');
plt.xlim([0,60])
plt.title('Avg HR as Pace Drops - Andrew')
plt.savefig('andrew_hrpace.jpg',dpi = 300)


# ax = plt.axes()
# plt.scatter(pace, calspmi, c = calspmi, alpha = .5)
# plt.plot(np.arange(0,20),np.ones(20)*np.ma.masked_invalid(r_avg_hr).mean(),'firebrick')
# plt.xlabel('Avg Pace (min/mi)');
# plt.ylabel('Calories/Mile');
# # plt.xlim([4,13])
# # plt.ylim([0,200])
# ax.invert_xaxis();
# plt.show()

# plt.figure()
# plt.scatter(pace, avg_hr, c = avg_hr, alpha = .5)
# plt.xlabel('Avg Pace (min/mi)');
# plt.ylabel('Heart Rate');
# # plt.xlim([4,13])
# plt.show()

# %%
# %matplotlib inline

runs_time = runs["Time"];
runs_distance = runs["Distance"];
runs_calories = runs["Calories"];

y = runs_time;
x = runs_distance;
z = runs_calories;

ax = plt.axes(projection='3d')
ax.scatter3D(runs_time, runs_distance, runs_calories,c = runs_calories)
ax.set_title('surface');
ax.view_init(60, 35)
ax.set_ylim([0,15])

# plt.figure()
# xi, yi = np.linspace(x.min(), x.max(), 1000), np.linspace(y.min(), y.max(), 1000)
# xi, yi = np.meshgrid(xi, yi)

# rbf = scipy.interpolate.Rbf(x, y, z, function='linear')
# zi = rbf(xi, yi)

# plt.imshow(zi, vmin=z.min(), vmax=z.max(), origin='lower',
#            extent=[x.min(), x.max(), y.min(), y.max()])
# #plt.scatter(x, y, c=z)
# plt.colorbar()
# plt.show()

# sca
# Out:
# (0.0, 15.0)
